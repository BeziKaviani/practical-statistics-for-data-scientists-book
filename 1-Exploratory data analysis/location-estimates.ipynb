# %%
import numpy as numpy
import pandas as pd
import scipy as sp

# %%
states = pd.read_csv("../datasets/states.csv")

# %%
states["Population"].mean()
# Out:
# 6162876.3

# %%
states["Population"].median()
# Out:
# 4436369.5

# %%
sp.stats.trim_mean(states["Population"], 0.1)
# Out:
# 4783697.125
